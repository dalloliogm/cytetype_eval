# %% [markdown]
# ### PS-s5e8 | [Binary Classification with a Bank Dataset](https://www.kaggle.com/competitions/playground-series-s5e8/code?competitionId=91719&sortBy=scoreDescending&excludeNonAccessedDatasources=true)
#
# All data on which [hv_blend](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend/) is based is stored in the section `DATASETS` and 100% relates to "their" solutions, which is reflected in each table
#
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.97_461 | &nbsp; v.5 &nbsp; | [PS-S5E8 . LightGB Model](https://www.kaggle.com/code/haohuanchen/ps-s5e8-lightgb-model) |  &nbsp; contributor &nbsp; | [HaohuanChen](https://www.kaggle.com/haohuanchen) | World |
# | 0.97_538 | &nbsp; v.5 &nbsp; | [Playground S5E8: Advanced LightGBM](https://www.kaggle.com/code/molozhenko/playground-s5e8-advanced-lightgbm/notebook) |  &nbsp; expert &nbsp; | [Evgeniy Molozhenko](https://www.kaggle.com/molozhenko) | World |
# | 0.97_5941 | &nbsp; v.3 &nbsp; | [Blend TUNING - Binary Classification](https://www.kaggle.com/code/tamareltech/blend-tuning-binary-classification/notebook) |  &nbsp; contributor &nbsp; | [Modelyst](https://www.kaggle.com/tamareltech) | World |
# | 0.97_5942 | &nbsp; v.3 &nbsp; | [Bank Classification . XGB+LGBM+CAT+NN+YDF](https://www.kaggle.com/code/mikhailnaumov/bank-classification-xgb-lgbm-cat-nn-ydf/notebook) |  &nbsp; expert &nbsp; | [Mikhail Naumov](https://www.kaggle.com/mikhailnaumov) | World |
# |  |  |  |  |  |  |
# |[0.97_638](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=254037266) | **v.14** | 3-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.15 +0.20 +0.25 +0.40 ] | [ 60 x 40 ](#parameters) | [ +0.15, -0.00, -0.05, -0.10 ] |
# |[0.97_639](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend) | **v.15** | 4-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.10 +0.15 +0.30 +0.45 ] | [ 60 x 40 ](#parameters) | [ +0.15, -0.00, -0.05, -0.10 ] |
# |[0.97_635](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=254044634) | **v.16** | 4-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.13 +0.17 +0.33 +0.37 ] | [ 60 x 40 ](#parameters) | [ +0.15, -0.00, -0.05, -0.10 ] |
# |[?](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend) | **v.17** | 4-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.09 +0.17 +0.27 +0.47 ] | [ 60 x 40 ](#parameters) | [ +0.11, -0.00, -0.04, -0.07 ] |
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.97_526 | &nbsp; v.2 &nbsp; | [Bank Classification. XGB+LGBM+CAT+NN](https://www.kaggle.com/code/mikhailnaumov/bank-classification-xgb-lgbm-cat-nn/notebook) |  &nbsp; expert &nbsp; | [Mikhail Naumov](https://www.kaggle.com/mikhailnaumov) | World |
# | 0.97_441 | &nbsp; v.17 &nbsp; | [Bank Term Deposit . Single LightGBM](https://www.kaggle.com/code/jiaoyouzhang/bank-term-deposit-single-lightgbm) |  &nbsp; master &nbsp; | [Less submissions](https://www.kaggle.com/jiaoyouzhang) | China |
# | 0.97_353 | &nbsp; v.1 &nbsp; | [Org+PSS5E8 : FLAML : roc_auc](https://www.kaggle.com/code/gauravduttakiit/org-pss5e8-flaml-roc-auc) |  &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# |  |  |  |  |  |  |
# |[0.97_559](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253901846) | **v.10** | 3-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.50 +0.30 +0.20 ] | [ 70 x 30 ](#parameters) | [ +0.10, -0.03, -0.07 ] |
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.97_526 | &nbsp; v.2 &nbsp; | [Bank Classification. XGB+LGBM+CAT+NN](https://www.kaggle.com/code/mikhailnaumov/bank-classification-xgb-lgbm-cat-nn/notebook) |  &nbsp; expert &nbsp; | [Mikhail Naumov](https://www.kaggle.com/mikhailnaumov) | World |
# | 0.97_450 | &nbsp; v.2 &nbsp; | [Playground S5E8: Enhanced LightGBM](https://www.kaggle.com/code/molozhenko/playground-s5e8-enhanced-lightgbm) |  &nbsp; expert &nbsp; | [Evgeniy Molozhenko](https://www.kaggle.com/molozhenko) | Russia |
# | 0.97_441 | &nbsp; v.17 &nbsp; | [Bank Term Deposit . Single LightGBM](https://www.kaggle.com/code/jiaoyouzhang/bank-term-deposit-single-lightgbm) |  &nbsp; master &nbsp; | [Less submissions](https://www.kaggle.com/jiaoyouzhang) | China |
# | 0.97_353 | &nbsp; v.1 &nbsp; | [Org+PSS5E8 : FLAML : roc_auc](https://www.kaggle.com/code/gauravduttakiit/org-pss5e8-flaml-roc-auc) |  &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# | 0.97_302 | &nbsp; v.1 &nbsp; | [Bank Term Deposit: Single LightGBM](https://www.kaggle.com/code/bizen250/bank-term-deposit-single-lightgbm) |  &nbsp; expert &nbsp; | [BIZEN250](https://www.kaggle.com/bizen250) | Japan |
# |  |  |  |  |  |  |
# |[0.97_599](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253903392) | **v.11** | 3-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.22 +0.21 +0.20 +0.19 +0.18 ] | [ 70 x 30 ](#parameters) | [ +0.04, +0.02, -0.01, -0.02, -0.03 ] |
# |[0.97_600](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253904375) | **v.12** | 3-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.23 +0.22 +0.20 +0.18 +0.17 ] | [ 70 x 30 ](#parameters) | [ +0.05, +0.02, -0.01, -0.02, -0.04 ] |
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.97_526 | &nbsp; v.2 &nbsp; | [Bank Classification. XGB+LGBM+CAT+NN](https://www.kaggle.com/code/mikhailnaumov/bank-classification-xgb-lgbm-cat-nn/notebook) |  &nbsp; expert &nbsp; | [Mikhail Naumov](https://www.kaggle.com/mikhailnaumov) | World |
# | 0.97_450 | &nbsp; v.2 &nbsp; | [Playground S5E8: Enhanced LightGBM](https://www.kaggle.com/code/molozhenko/playground-s5e8-enhanced-lightgbm) |  &nbsp; expert &nbsp; | [Evgeniy Molozhenko](https://www.kaggle.com/molozhenko) | Russia |
# | 0.97_441 | &nbsp; v.17 &nbsp; | [Bank Term Deposit . Single LightGBM](https://www.kaggle.com/code/jiaoyouzhang/bank-term-deposit-single-lightgbm) |  &nbsp; master &nbsp; | [Less submissions](https://www.kaggle.com/jiaoyouzhang) | China |
# | 0.97_353 | &nbsp; v.1 &nbsp; | [Org+PSS5E8 : FLAML : roc_auc](https://www.kaggle.com/code/gauravduttakiit/org-pss5e8-flaml-roc-auc) |  &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# | 0.97_302 | &nbsp; v.1 &nbsp; | [Bank Term Deposit: Single LightGBM](https://www.kaggle.com/code/bizen250/bank-term-deposit-single-lightgbm) |  &nbsp; expert &nbsp; | [BIZEN250](https://www.kaggle.com/bizen250) | Japan |
# | 0.97_298 | &nbsp; v.1 &nbsp; | [PSS5E8 : FLAML : roc_auc](https://www.kaggle.com/code/gauravduttakiit/pss5e8-flaml-roc-auc) |  &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# | 0.97_245 | &nbsp; v.2 &nbsp; | [Subscribe or not?](https://www.kaggle.com/code/darkdevil18/0-97245-subscribe-or-not) | &nbsp; mast.+ cont. &nbsp; | &nbsp; [D.S.Barik](https://www.kaggle.com/darkdevil18) + [R.Maity](https://www.kaggle.com/maityritwik) &nbsp; | India |
# | 0.97_118 | &nbsp; v.1 &nbsp; | [PSS5E8 : best_quality : gpu](https://www.kaggle.com/code/gauravduttakiit/pss5e8-best-quality-gpu) | &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# | 0.97_109 | &nbsp; v.2 &nbsp; | [AutoGluon Tutorial : Fast & Furious](https://www.kaggle.com/code/codingloading/autogluon-tutorial-fast-furious) | &nbsp; expert &nbsp; | &nbsp; [YouTuber @DataScience](https://www.kaggle.com/codingloading) &nbsp; | India
# |  |  |  |  |  |  |
# |[0.97609](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253907602) | **v.13** | 3-august-2025 &nbsp;&nbsp;[hv_blend](#blend)&nbsp;&nbsp; [0.19 +0.17 +0.15 +0.13 ...](#parameters)| [ 70 x 30 ](#parameters) |[+0.050, +0.035, +0.015, +0.005, ...](#parameters)|
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.97_450 | &nbsp; v.2 &nbsp; | [Playground S5E8: Enhanced LightGBM](https://www.kaggle.com/code/molozhenko/playground-s5e8-enhanced-lightgbm) |  &nbsp; expert &nbsp; | [Evgeniy Molozhenko](https://www.kaggle.com/molozhenko) | Russia |
# | 0.97_302 | &nbsp; v.1 &nbsp; | [Bank Term Deposit: Single LightGBM](https://www.kaggle.com/code/bizen250/bank-term-deposit-single-lightgbm) |  &nbsp; expert &nbsp; | [BIZEN250](https://www.kaggle.com/bizen250) | Japan |
# | 0.97_298 | &nbsp; v.1 &nbsp; | [PSS5E8 : FLAML : roc_auc](https://www.kaggle.com/code/gauravduttakiit/pss5e8-flaml-roc-auc) |  &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# | 0.97_245 | &nbsp; v.2 &nbsp; | [Subscribe or not?](https://www.kaggle.com/code/darkdevil18/0-97245-subscribe-or-not) | &nbsp; mast.+ cont. &nbsp; | &nbsp; [D.S.Barik](https://www.kaggle.com/darkdevil18) + [R.Maity](https://www.kaggle.com/maityritwik) &nbsp; | India |
# | 0.97_109 | &nbsp; v.2 &nbsp; | [AutoGluon Tutorial : Fast & Furious](https://www.kaggle.com/code/codingloading/autogluon-tutorial-fast-furious) | &nbsp; expert &nbsp; | &nbsp; [YouTuber @DataScience](https://www.kaggle.com/codingloading) &nbsp; | India |
# |  |  |  |  |  |  |
# |[0.97_564](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253787512) | **v.5** | 2-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.45 +0.25 +0.15 +0.10 +0.05 ] | [ 70 x 30 ](#parameters) | [ +0.04, +0.02, -0.01, -0.02, -0.03 ] |
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.97_302 | &nbsp; v.1 &nbsp; | [Bank Term Deposit: Single LightGBM](https://www.kaggle.com/code/bizen250/bank-term-deposit-single-lightgbm) |  &nbsp; expert &nbsp; | [BIZEN250](https://www.kaggle.com/bizen250) | Japan |
# | 0.97_298 | &nbsp; v.1 &nbsp; | [PSS5E8 : FLAML : roc_auc](https://www.kaggle.com/code/gauravduttakiit/pss5e8-flaml-roc-auc) |  &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# | 0.97_245 | &nbsp; v.2 &nbsp; | [Subscribe or not?](https://www.kaggle.com/code/darkdevil18/0-97245-subscribe-or-not) | &nbsp; mast.+ cont. &nbsp; | &nbsp; [D.S.Barik](https://www.kaggle.com/darkdevil18) + [R.Maity](https://www.kaggle.com/maityritwik) &nbsp; | India |
# | 0.97_118 | &nbsp; v.1 &nbsp; | [PSS5E8 : best_quality : gpu](https://www.kaggle.com/code/gauravduttakiit/pss5e8-best-quality-gpu) | &nbsp; master &nbsp; | [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) | India |
# | 0.97_109 | &nbsp; v.2 &nbsp; | [AutoGluon Tutorial : Fast & Furious](https://www.kaggle.com/code/codingloading/autogluon-tutorial-fast-furious) | &nbsp; expert &nbsp; | &nbsp; [YouTuber @DataScience](https://www.kaggle.com/codingloading) &nbsp; | India |
# |  |  |  |  |  |  |
# |[0.97_586](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253776402) | **v.4** | 2-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.40 +0.30 +0.20 +0.05 +0.05 ] | [ 70 x 30 ](#parameters) | [ +0.04, +0.02, -0.01, -0.02, -0.03 ] |
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.97_098 | &nbsp; v.1 &nbsp; | [Best Banker -autogluon 🤑 lb - 0.97098](https://www.kaggle.com/code/arnavsuiiiiiiiiiiii/best-banker-autogluon-lb-0-97098) |  &nbsp; expert &nbsp; | [ARNAV PANDEY](https://www.kaggle.com/arnavsuiiiiiiiiiiii) | World |
# | 0.97_068 | &nbsp; v.3 &nbsp; | [Playground S5E8: Stacked Ensemble](https://www.kaggle.com/code/molozhenko/playground-s5e8-stacked-ensemble) |  &nbsp; expert &nbsp; | [Evgeniy Molozhenko](https://www.kaggle.com/molozhenko) | Russia |
# | 0.97_065 | &nbsp; v.1 &nbsp; | [PSS5E8 : good_quality : gpu](https://www.kaggle.com/code/gauravduttakiit/pss5e8-good-quality-gpu) | &nbsp; master &nbsp; | &nbsp; [Gaurav Dutta](https://www.kaggle.com/gauravduttakiit) &nbsp; | India |
# | 0.97_055 | &nbsp; v.1 &nbsp; | [Bank Classification. XGB+LGBM](https://www.kaggle.com/code/mikhailnaumov/bank-classification-xgb-lgbm) | &nbsp; expert &nbsp; | &nbsp; [Mikhail Naumov](https://www.kaggle.com/mikhailnaumov) &nbsp; | World |
# | 0.97_044 | &nbsp; v.24 &nbsp; | [PGS5E8 - Bank Autogluon](https://www.kaggle.com/code/dalloliogm/pgs5e8-bank-autogluon) | &nbsp; expert &nbsp; | &nbsp; [Giovanni Marco Dall'Olio](https://www.kaggle.com/dalloliogm) &nbsp; | England |
# |  |  |  |  |  |  |
# |[0.97_105](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253768175) | **v.2** | 2-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.22 +0.21 +0.20 +0.19 +0.18 ] | [ 70 x 30 ](#parameters) | [ +0.07, +0.02, -0.01, -0.03, -0.05 ] |
# |[0.97_114](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend?scriptVersionId=253769479) | **v.3** | 2-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.60 +0.10 +0.10 +0.10 +0.10 ] | [ 70 x 30 ](#parameters) | [ +0.07, +0.02, -0.01, -0.03, -0.05 ] |
#
# &nbsp;
#
# | &nbsp; | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# | - | :-: | :- | :-: | :-: | -: |
# | 0.96_981 | &nbsp; v.2 &nbsp;| [Bank Term Deposit . LightGBM](https://www.kaggle.com/code/jiaoyouzhang/bank-term-deposit-lightgbm?scriptVersionId=253587629) |  &nbsp; master &nbsp; | [Less submissions](https://www.kaggle.com/jiaoyouzhang) | China |
# | 0.96_799 | &nbsp; v.1 &nbsp;| [S5E8 . VotingClassifier . RF+XGB+LGBM+CatBoost](https://www.kaggle.com/code/rohansardar/s5e8-votingclassifier-rf-xgb-lgbm-catboost) |  &nbsp; expert &nbsp; | [Rohan Sardar](https://www.kaggle.com/rohansardar) | India |
# | 0.96_781 | &nbsp; v.4 &nbsp;| [S5E8 . VotingClassifier](https://www.kaggle.com/code/qifeihhh666/s5e8-votingclassifier) | &nbsp; expert &nbsp; | &nbsp; [耶✌](https://www.kaggle.com/qifeihhh666) &nbsp; | World |
# | 0.96_778 | &nbsp; v.1 &nbsp;| [Binary Bank Problem - XGB](https://www.kaggle.com/code/abdmental01/binary-bank-problem-xgb) | grandmaster | &nbsp; [Sheikh Muhammad Abdullah](https://www.kaggle.com/abdmental01) &nbsp; | Pakistan |
# | 0.96_618 | &nbsp; v.4 &nbsp;| [sklearn . Predicting Bank Deposit Subscriptions](https://www.kaggle.com/code/petermoorhouse/sklearn-predicting-bank-deposit-subscriptions) | &nbsp; expert &nbsp; | &nbsp; [Peter Moorhouse](https://www.kaggle.com/petermoorhouse) &nbsp; | England |
# |  |  |  |  |  |  |
# |[0.96_987](https://www.kaggle.com/code/nina2025/ps-s5e7-binary-classification-hv-blend/notebook?scriptVersionId=253606151) | **v.1** | 1-august-2025 &nbsp;&nbsp; [hv_blend](#blend) &nbsp;&nbsp; [ 0.80 +0.05 +0.05 +0.05 +0.05 ] | [ 70 x 30 ](#parameters) | [ +0.07, +0.02, -0.01, -0.03, -0.05 ] |

# %% [markdown]
# First glance - EDA:
# - [20250801_PGS5E8_EDA](https://www.kaggle.com/code/elainedazzio/20250801-pgs5e8-eda) by expert [L. Elaine Dazzio](https://www.kaggle.com/elainedazzio)
# - [Binary Bank termdipäzet](https://www.kaggle.com/code/mpwolke/binary-bank-termdip-zet) by granmaster [Marília Prata](https://www.kaggle.com/mpwolke)
#
# Second glance - EDA + active.solution:
# - [Bank Classification| XGB+LGBM](https://www.kaggle.com/code/mikhailnaumov/bank-classification-xgb-lgbm) by expert [Mikhail Naumov](https://www.kaggle.com/mikhailnaumov)
# - [🏦 Playground S5E8 | Bank Marketing EDA + Stacking](https://www.kaggle.com/code/analyticaobscura/playground-s5e8-bank-marketing-eda-stacking) by master [OzanM.](https://www.kaggle.com/analyticaobscura)
#
# Third glance:
# - [🏦PS S5/E08 - Bank Data Binary Classification](https://www.kaggle.com/code/docxian/ps-s5-e08-bank-data-binary-classification) by master [Chris X](https://www.kaggle.com/docxian)
# - It is planned to attempt to recode all feats into numeric variables + FE -> HS
# - It is also planned to connect a vertical depth blend

# %%
import pandas as pd

# %% [markdown]
# ### blend

# %%
# blend

def hv_blend(path_to_ds, file_short_names, dk):

    def da(dk,sorting_direction):
        
        def read_subm(dk,i):
            tnm = dk["subm"][i]["name"]
            FiN = dk["path"] + tnm + ".csv"
            return pd.read_csv(FiN).rename(columns={'target':tnm, dk["target"]:tnm})
        
        dfs_subm = [read_subm(dk,i) for i in range(len(dk["subm"]))]
        
        df_subms = pd.merge(dfs_subm[0],  dfs_subm[1], on=[dk['id']])
        for i in range(2, len(dk["subm"])): 
            df_subms = pd.merge(df_subms, dfs_subm[i], on=[dk['id']])
            
        cols = [col for col in df_subms.columns if col != dk['id']]
        short_name_cols = [c for c in cols]
        corrects = [wt for wt in dk["subwts"]]
        weights = [subm['weight'] for subm in dk["subm"]]
        
        def alls(x, sd=sorting_direction,cs=cols):
            reverse = True if sd=='desc' else False
            tes = {c: x[c] for c in cs}.items()
            subms_sorted = [t[0] for t in sorted(tes,key=lambda k:k[1],reverse=reverse)]
            return subms_sorted
        
        def correct(x, cs=cols, w=weights, cw=corrects):
            ic = [x['alls'].index(c) for c in short_name_cols]
            cS = [x[cols[j]] * (w[j] + cw[ic[j]]) for j in range(len(cols))]
            return sum(cS)
        
        df_subms['alls']       = df_subms.apply(lambda x: alls   (x), axis=1)
        df_subms[dk["target"]] = df_subms.apply(lambda x: correct(x), axis=1)
        
        schema_rename = { old_nc:new_shnc for old_nc, new_shnc in zip(cols, short_name_cols) }
        
        df_subms = df_subms.rename(columns=schema_rename)
        df_subms = df_subms.rename(columns={dk["target"]:"ensemble"})
        
        df_subms.insert(loc=1, column=' _ ', value=['   '] * len(df_subms)) #dk["q_rows"])
        
        df_subms[' _ '] = df_subms[' _ '].astype(str)
        pd.set_option('display.max_rows',100)
        pd.set_option('display.float_format', '{:.4f}'.format)
        vcols = [dk['id']]+[' _ '] + short_name_cols + [' _ ']+['alls']+[' _ ']+['ensemble']
        df_subms = df_subms[vcols]
        display(df_subms.head(8))
        pd.set_option('display.float_format', '{:.5f}'.format)
        df_subms = df_subms.rename(columns={"ensemble":dk["target"]})
        
        return df_subms
        

    sample_subm = pd.read_csv(path_to_ds + file_short_names[1] + ".csv")

    
    def ensemble_da(dk,submission=sample_subm): 
        _id,target,d,a = dk['id'],dk['target'],dk['desc'],dk['asc']
        dfs = da(dk,'desc')
        dfD = dfs[[_id, target]]
        dfD.to_csv(f'tida_desc.csv', index=False)
        dfs = da(dk,'asc')
        dfA = dfs[[_id, target]]
        dfA.to_csv(f'tida_asc.csv',  index=False)
        submission[target] = dfD[target] * d + a * dfA[target]
        return submission

    submission = ensemble_da(dk)
    
    return submission

# %% [markdown]
# ### parameters

# %%
# archive

# path_to_ds ='/kaggle/input/1-august-2025-ps-s5e8/' + 'submission '

# file_short_names = ['0.96981','0.96799','0.96781','0.96778','0.96618']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'prefix' : "subm_",
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.07, +0.02, -0.01, -0.03, -0.05],              # Lb=0.96987
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.80, },
#          { 'name':file_short_names[1],'weight':0.05, },
#          { 'name':file_short_names[2],'weight':0.05, },
#          { 'name':file_short_names[3],'weight':0.05, },
#          { 'name':file_short_names[4],'weight':0.05, },
#       ]
#     }


# path_to_ds ='/kaggle/input/2-august-2025-ps-s5e8/' + 'submission '


# file_short_names = ['0.97098','0.97068','0.97065','0.97055','0.97044']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'prefix' : "subm_",
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.07, +0.02, -0.01, -0.03, -0.05],              # Lb=0.97_105
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.22, },
#          { 'name':file_short_names[1],'weight':0.21, },
#          { 'name':file_short_names[2],'weight':0.20, },
#          { 'name':file_short_names[3],'weight':0.19, },
#          { 'name':file_short_names[4],'weight':0.18, },
#       ]
#     }

# file_short_names = ['0.97098','0.97068','0.97065','0.97055','0.97044']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'prefix' : "subm_",
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.07, +0.02, -0.01, -0.03, -0.05],              # Lb=0.97_114
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.60, },
#          { 'name':file_short_names[1],'weight':0.10, },
#          { 'name':file_short_names[2],'weight':0.10, },
#          { 'name':file_short_names[3],'weight':0.10, },
#          { 'name':file_short_names[4],'weight':0.10, },
#       ]
#     }

# file_short_names = ['0.97302','0.97298','0.97245','0.97118','0.97109']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'prefix' : "subm_",
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.04, +0.02, -0.01, -0.02, -0.03],              # Lb=0.97_586
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.40, },
#          { 'name':file_short_names[1],'weight':0.30, },
#          { 'name':file_short_names[2],'weight':0.20, },
#          { 'name':file_short_names[3],'weight':0.05, },
#          { 'name':file_short_names[4],'weight':0.05, },
#       ]
#     }


# file_short_names = ['0.97450','0.97302','0.97298','0.97245','0.97109']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'prefix' : "subm_",
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.04, +0.02, -0.01, -0.02, -0.03],              # Lb=0.97564
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.45, },
#          { 'name':file_short_names[1],'weight':0.25, },
#          { 'name':file_short_names[2],'weight':0.15, },
#          { 'name':file_short_names[3],'weight':0.10, },
#          { 'name':file_short_names[4],'weight':0.05, },
#       ]
#     }

# file_short_names = ['0.97302','0.97298','0.97245','0.97118','0.97109']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'prefix' : "subm_",
#       'desc'   : 0.72,
#       'asc'    : 0.28,
#       'subwts' : [+0.044, +0.03, -0.01, -0.024, -0.04],              # Lb=?
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.40, },
#          { 'name':file_short_names[1],'weight':0.30, },
#          { 'name':file_short_names[2],'weight':0.20, },
#          { 'name':file_short_names[3],'weight':0.05, },
#          { 'name':file_short_names[4],'weight':0.05, },
#       ]
#     }


# df = hv_blend ( path_to_ds, file_short_names, params )

# df.to_csv('submission.csv', index=False)

# display(df)


# path_to_ds ='/kaggle/input/2-august-2025-ps-s5e8/' + 'submission '


# file_short_names = ['0.97526','0.97441','0.97353']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.10, -0.03, -0.07],                            # Lb=0.97559
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.50, },
#          { 'name':file_short_names[1],'weight':0.30, },
#          { 'name':file_short_names[2],'weight':0.20, },
#       ]
#     }

# file_short_names = ['0.97526','0.97450','0.97441','0.97353','0.97302']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.04, +0.02, -0.01, -0.02, -0.03],              # Lb=0.97599
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.22, },
#          { 'name':file_short_names[1],'weight':0.21, },
#          { 'name':file_short_names[2],'weight':0.20, },
#          { 'name':file_short_names[3],'weight':0.19, },
#          { 'name':file_short_names[4],'weight':0.18, },
#       ]
#     }

# file_short_names = ['0.97526','0.97450','0.97441','0.97353','0.97302']
# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.05, +0.02, -0.01, -0.02, -0.04],              # Lb=0.97600
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.23, },
#          { 'name':file_short_names[1],'weight':0.22, },
#          { 'name':file_short_names[2],'weight':0.20, },
#          { 'name':file_short_names[3],'weight':0.18, },
#          { 'name':file_short_names[4],'weight':0.17, },
#       ]
#     }

# file_short_names = [
#     '0.97526','0.97450','0.97441','0.97353','0.97302','0.97298','0.97245','0.97118','0.97109']

# params = {
#       'path'   : path_to_ds,                                 
#       'sort'   : "asc/desc",
#       'id'     : 'id',
#       'target' : "y",                                              # Lb=0.97609
#       'q_rows' : 250_000,                                         
#       'desc'   : 0.70,
#       'asc'    : 0.30,
#       'subwts' : [+0.050, +0.035, +0.015, +0.005, -0.010, -0.015, -0.020, -0.025, -0.035],              
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.19, }, # 0.19
#          { 'name':file_short_names[1],'weight':0.17, }, # 0.36
#          { 'name':file_short_names[2],'weight':0.15, }, # 0.51
#          { 'name':file_short_names[3],'weight':0.13, }, # 0.64
#          { 'name':file_short_names[4],'weight':0.10, }, # 0.74
#          { 'name':file_short_names[5],'weight':0.09, }, # 0.83
#          { 'name':file_short_names[6],'weight':0.08, }, # 0.91
#          { 'name':file_short_names[7],'weight':0.05, }, # 0.96
#          { 'name':file_short_names[8],'weight':0.04, }, # 1.00
#       ]
#     }

# %%
path ='/kaggle/input/3-august-2025-ps-s5e8/' + 'submission '

file_short_names = ['0.97461','0.97538','0.975941','0.975942']

# params = {
#       'path'   : path,
#       'id'     : 'id',
#       'target' : "y",
#       'q_rows' : 250_000,
#       'desc'   : 0.60,
#       'asc'    : 0.40,
#       'subwts' : [+0.15, 0.00, -0.05, -0.10],            # Lb=0.97638
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.15, },
#          { 'name':file_short_names[1],'weight':0.20, },
#          { 'name':file_short_names[2],'weight':0.25, },
#          { 'name':file_short_names[3],'weight':0.40, },
#       ]
#     }

# params = {
#       'path'   : path,
#       'id'     : 'id',
#       'target' : "y",
#       'desc'   : 0.60,
#       'asc'    : 0.40,
#       'subwts' : [+0.15, 0.00, -0.05, -0.10],            # Lb=0.97639
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.10, },
#          { 'name':file_short_names[1],'weight':0.15, },
#          { 'name':file_short_names[2],'weight':0.30, },
#          { 'name':file_short_names[3],'weight':0.45, },
#       ]
#     }

# params = {
#       'path'   : path,
#       'id'     : 'id',
#       'target' : "y",
#       'desc'   : 0.60,
#       'asc'    : 0.40,
#       'subwts' : [+0.15, 0.00, -0.05, -0.10],            # Lb=0.97635
#       'subm'   : [
#          { 'name':file_short_names[0],'weight':0.13, },
#          { 'name':file_short_names[1],'weight':0.17, },
#          { 'name':file_short_names[2],'weight':0.33, },
#          { 'name':file_short_names[3],'weight':0.37, },
#       ]
#     }

params = {
      'path'   : path,
      'id'     : 'id',
      'target' : "y",
      'desc'   : 0.60,
      'asc'    : 0.40,
      'subwts' : [+0.11, 0.00, -0.04, -0.07],            # Lb=?
      'subm'   : [
         { 'name':file_short_names[0],'weight':0.09, },
         { 'name':file_short_names[1],'weight':0.17, },
         { 'name':file_short_names[2],'weight':0.27, },
         { 'name':file_short_names[3],'weight':0.47, },
      ]
    }

# %%
df = hv_blend ( path, file_short_names, params )

df.to_csv('submission.csv', index=False)

display(df)
# Out:
#        id   _   0.97461  0.97538  0.975941  0.975942   _   \
# 0  750000        0.0032   0.0011    0.0022    0.0160
# 1  750001        0.0721   0.1263    0.0901    0.0396
# 2  750002        0.0002   0.0002    0.0002    0.0159
# 3  750003        0.0000   0.0002    0.0001    0.0158
# 4  750004        0.0159   0.0179    0.0193    0.0171
# 5  750005        0.0008   0.0016    0.0018    0.0161
# 6  750006        0.4033   0.3557    0.3638    0.2978
# 7  750007        0.5492   0.6969    0.5650    0.7430
#
#                                      alls   _   ensemble
# 0  [0.975942, 0.97461, 0.975941, 0.97538]         0.0102
# 1  [0.97538, 0.975941, 0.97461, 0.975942]         0.0791
# 2  [0.975942, 0.97461, 0.975941, 0.97538]         0.0093
# 3  [0.975942, 0.97538, 0.975941, 0.97461]         0.0092
# 4  [0.975941, 0.97538, 0.975942, 0.97461]         0.0180
# 5  [0.975942, 0.975941, 0.97538, 0.97461]         0.0100
# 6  [0.97461, 0.975941, 0.97538, 0.975942]         0.3442
# ...
