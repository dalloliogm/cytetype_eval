# %% [markdown]
# <a href="https://www.kaggle.com/code/dalloliogm/cytetype-exploration-1?scriptVersionId=251163816" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Evaluation of CyteType
#
# CyteType is a tool for automatic curation of cell types in single cell, using an LLM Annotator Agent.
#
# In this notebook, we try the tool on a few datasets and compare it with other annotation tools.

# %% [markdown]
# ### Install Libraries

# %%
# !python -m pip install -q cytetype scanpy igraph leidenalg
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 78.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 3.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# ydata-profiling 4.16.1 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.3 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
import anndata
import scanpy as sc
import cytetype
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialize Paul15 dataset
#
# The Paul et al 2015 dataset is a small single-cell dataset of myeloid cells, available from scanpy. The Cell types have been manually annotated, meaning we can compare cytetype's predictions against the true values.

# %%
#adata = sc.datasets.paul15()

# %%
import os
import scanpy as sc

if not os.path.exists("paul15_small.h5ad"):
    adata = sc.datasets.paul15()
    adata.write("paul15_small.h5ad")
else:
    adata = sc.read("paul15_small.h5ad")
# Out:
#   0%|          | 0.00/9.82M [00:00<?, ?B/s]
# ... storing 'paul15_clusters' as categorical

# %% [markdown]
# ### Process the data - compute clusters, etc

# %%
adata.obs["paul15_clusters"]
# Out:
# W31105      7MEP
# W31106      15Mo
# W31107      3Ery
# W31108      15Mo
# W31109      3Ery
#            ...
# W39164      2Ery
# W39165    13Baso
# W39166      7MEP
# W39167      15Mo
# W39168      3Ery
# Name: paul15_clusters, Length: 2730, dtype: category
# Categories (19, object): ['1Ery', '2Ery', '3Ery', '4Ery', ..., '16Neu', '17Neu', '18Eos', '19Lymph']

# %%
# Load and preprocess your data
adata.var["gene_symbols"] = adata.var_names

# We compute the clusters as suggested by the tutorial
# However, this produces 10 clusters. We are going to use the 19
# clusters from the original paper, which are stored in the `paul15_clusters` column.
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.leiden(adata)
sc.tl.rank_genes_groups(adata, groupby='paul15_clusters', method='t-test')

# Initialize CyteType (performs data preparation)
annotator = cytetype.CyteType(
    adata,
    group_key='paul15_clusters',           # Required: cluster column name
    rank_key='rank_genes_groups',          # DE results key (default)
    gene_symbols_column='gene_symbols',    # Gene symbols column (default)
    n_top_genes=50,                        # Top marker genes per cluster
    #results_prefix='cytetype'              # Prefix for result columns
)
# Out:
# 2025-07-18 09:19:09.804240: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752830350.076424      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752830350.158992      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /tmp/ipykernel_13/798197818.py:11: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata)
# Using coordinates from 'X_pca' for visualization.
# Calculating expression percentages.
# Extracting marker genes.
# Preparing visualization data with sampling.
# Using first 2 dimensions of 'X_pca' for visualization.
# Extracted 2730 coordinate points (sampled from 2730 total cells)
# Data preparation completed. Ready for submitting jobs.

# %%
# 1. Grab the result dict
res = adata.uns['rank_genes_groups']

# 2. Extract the structured array of gene names
#    This is a numpy recarray whose field names are your cluster labels,
#    e.g. ('0', '1', …, '14').
names = res['names']

# 3. Get the list of clusters:
clusters = names.dtype.names
print("Clusters found:", clusters)

# 4. Loop through and print top 50 per cluster
for cl in clusters:
    top50 = names[cl][:50]
    print(f"\nCluster {cl} — top 50 markers:")
    print(", ".join(top50))
# Out:
# Clusters found: ('1Ery', '2Ery', '3Ery', '4Ery', '5Ery', '6Ery', '7MEP', '8Mk', '9GMP', '10GMP', '11DC', '12Baso', '13Baso', '14Mo', '15Mo', '16Neu', '17Neu', '18Eos', '19Lymph')
#
# Cluster 1Ery — top 50 markers:
# Car2, Fam132a, Blvrb, Prdx2, Klf1, Ctse, Cpox, Rhd, Fth1, Hemgn, Glrx5, Tmem14c, Zfpm1, Stard10, Ifrd2, Ubac1, Mcm2, Hba-a2, Ermap, Mns1, Cldn13, Sod1, Mcm7, Hdgf, Hmbs, Isg20, Aqp1, Alad, Cd24a, Ap1b1, Spnb1, Atpif1, Ccne1, Mcm5, Tuba1b, Atp5a1, Tnfaip2, Ppp2r4, Ank1, Cited4, Ucp2, Hbb-b1, Pklr, Tubb5, Necap2, Tk1, Grina, Atp5b, Cyc1, Bsg
#
# Cluster 2Ery — top 50 markers:
# Fam132a, Blvrb, Car2, Mt2, Klf1, Prdx2, Rhd, Ermap, Cpox, Ctse, Aqp1, Sphk1, Stard10, Alad, Car1, Fth1, Tmem14c, Mthfd1, Glrx5, Hmbs, Pla2g12a, Mns1, Mt1, Cd24a, Atpif1, Sod1, Mrpl52, Lmna, Tnfaip2, Atp1b2, Ap1b1, Cenp-a, Urod, Hdgf, Isg20, Cldn13, Epor, Ifrd2, Cited4, Pklr, Phb2, Nudt9, Tubb5, Eif4ebp1, Abcb4, Ttll12, Zfpm1, Necap2, Add2, Gata1
#
# Cluster 3Ery — top 50 markers:
# Car2, Ermap, Mt2, Fam132a, Klf1, Blvrb, Cpox, Tnfaip2, Abcb4, Mthfd1, Mt1, Atp1b2, Zfpm1, Hdgf, Sphk1, Rhd, Alad, Mns1, Aqp1, Glrx5, Prdx2, Spire1, Aplp2, Urod, Nolc1, Ddx21, Tmem14c, Hspd1, Metap2, Vamp5, Add2, Ahctf1, Csda, Epor, Hk1, Eif4g1, Gata1, Cct6a, Stard10, Car1, Mrpl52, Pla2g12a, Gclm, Tspan33, Myh10, Nudt9, Abcf1, Txnl1, Eif4b, Etf1
#
# Cluster 4Ery — top 50 markers:
# Car2, Car1, Blvrb, Fam132a, Klf1, Mt2, Ermap, Cpox, Mthfd1, Sphk1, Mns1, Hdgf, Prdx2, Mt1, Aqp1, Csda, Tnfaip2, Fth1, Atp1b2, Cyc1, Alad, Rhd, Ncl, Zfpm1, Mybbp1a, Stard10, Glrx5, Mrpl52, Eif3b, Hspd1, Gclm, Chchd10, Gata1, Nolc1, Hk1, Vamp5, Tmem14c, Pabpn1, Abcb4, Prdx6, Necap2, Cenp-a, Lyar, Ybx1, Asns, Ppm1g, Aplp2, Ahctf1, Eif4ebp1, Phb2
#
# Cluster 5Ery — top 50 markers:
# Car1, Atpif1, Mt1, Car2, Blvrb, Klf1, Mt2, Prdx6, Vamp5, Aqp1, Mrpl52, Tnfaip2, Hk1, Rpl4, Ermap, Zfpm1, Mthfd1, Tuba1b, Eef1g, Gnb2l1, Atp1b2, Fth1, Cct3, Alad, Hdgf, Chchd2, Sphk1, Mybbp1a, Fam132a, Rhd, AK158095, Csda, Prdx2, Mns1, Cox6b2, Sod1, Lgals9, Pdlim1, Cpox, Hspa8, Kcnn4, Mdh2, Gata1, Tubb5, Cad, Hspe1, Urod, Eif4ebp1, Epor, Cct7
#
# Cluster 6Ery — top 50 markers:
# Car1, Apoe, Gnb2l1, Eef2, Atpif1, Vamp5, Rpl13a, Car2, Aqp1, Rps3, Prdx6, S100a10, Mfsd2b, Klf1, Mt1, Ptprcap, Optn, Crip1, Txnip, Myc, Myb, Smap2, Ermap, Gata2, Zg16, Rps20, Atp1b2, Lgals9, Lpin2, Hk1, Tspo2, Cbfa2t3, Rps19, Grb10, Samd14, Sdsl, Rab4a, Khk, Blvrb, Add1, Pdlim1, Trib2, Ldb1, Zfpm1, 2410006H16Rik, Slc22a3, Plxnc1, Golm1, Glipr2, Nrgn
#
# Cluster 7MEP — top 50 markers:
# Apoe, Txnip, Gata2, S100a10, Ptprcap, Malat1, Gnb2l1, Vamp5, Muc13, F2r, Nfe2, Mfsd2b, Sox4, Spns2, 2410006H16Rik, Sipa1l1, Slc22a3, Ndrg1, Cbfa2t3, Ypel3, Kdm5b, Ifitm1, Lpin2, BC029331, Gpr56, Ptpn14, Galnt6, Abcg1, Zyx, Rab37, Vim, Akap13, 1110013L07Rik, 2210020M01Rik, H2-T10, Arhgef2, Arap3, Gas5, Rps3, Lat, Optn, Treml2, Fam117a, Zfpm1, Rnf125, Nrgn, Fam65a, Grb2, Iqgap2, Rpl4
#
# Cluster 8Mk — top 50 markers:
# Gpr56, Serpina3f, Nrgn, Zyx, Apoe, Itga2b, Pbx1, Rap1b, Cd9, Gata2, Pf4, Dapp1, F2r, Actb, Cdcrel-1, Cited2, Zfpm1, Tuba8, Ifitm3, Mef2c, Lat, Tgfb1, BC029331, Slc14a1, Sdpr, mKIAA1027, Mycn, Itgb3, Hipk1, Gp9, Plek, Ehd3, Meis1, Mpl, Unc119, Vwf, Runx1, Muc13, Mfsd2b, mKIAA0569, Vamp5, Fli1, Rab27b, Rbpms, Tbxas1, Gp5, Rab37, Arhgap6, Cbfa2t3, Nrip1
#
# Cluster 9GMP — top 50 markers:
# Gpr56, H2afy, Serpina3f, Tmem176b, Spns2, Coro1a, Laptm5, Ptprcap, Sox4, Zyx, Pnrc1, Akap13, Eltd1, Muc13, Cd27, Fam117a, Actb, Pkm2, Wdfy4, Dapp1, Flt3, Igfbp4, Fxyd5, Ptpn18, Trf, Marcksl1, Aff3, Nrgn, Spnb2, Tmem176a, Il16, Slc22a3, Ptpre, Lsp1, Syk, Osbpl8, Slfn8, Arhgdib, Arhgap30, Mdga1, Apoe, Lat2, Ramp1, Chd3, Fam168b, Nfe2, Cd34, Etv6, Nfatc1, Zfp608
#
# Cluster 10GMP — top 50 markers:
# H2afy, Tmem176b, Gpr56, Rps3, Sh3bgrl3, Cd34, Serpina3f, Cd27, Ptprcap, Coro1a, Flt3, Fxyd5, Ifitm1, Laptm5, Lsp1, Sell, Vim, Pkm2, Eltd1, Plcg2, Psmb8, Sox4, Nrgn, Tmsb10, Coro2a, Satb1, Rps3a, Dctpp1, Rac2, Zyx, Lcp1, Trf, Aff3, Ifitm3, Parvg, Ifi203, Tmem176a, Arhgdib, Cd52, Actb, Rbpms, Bex6, Il16, Irf8, Etv6, Egfl7, Dntt, Bin1, Fr1, Il4ra
#
# Cluster 11DC — top 50 markers:
# Actb, Cd74, Laptm5, Lsp1, Cd52, Cst3, H2-Ab1, Ifi30, Id2, Tmsb10, Crip1, H2-Aa, H2-Eb1, Ucp2, Vim, Wdfy4, Lrrc58, Coro1a, Itgb7, Irf8, Ly6e, Plbd1, Selplg, Lgals3, Psap, Anxa2, Anxa6, NAAA, Calm1, H2-DMb1, 5430435G22Rik, Arhgdia, Cyba, H2-DMa, Cnn2, Pld4, Grn, Ctss, Rgs2, Lgals1, Psmb8, Fxyd5, Anxa5, Aif1, Ahnak, Ctsh, Hck, Klf4, Gsn, Gm2a
#
# Cluster 12Baso — top 50 markers:
# Apoe, Srgn, Lmo4, Gata2, Gpr56, Ifitm1, Ly6e, Lgals1, Hdc, Fut7, Vim, Laptm5, Rin3, Gm2a, Runx1, Rps3, Ptprcap, Fam129a, Muc13, Ypel3, S100a10, Ptprs, Dapp1, Fxyd5, Zyx, Spns2, Galnt6, Csf2rb, Itga2b, Coro1a, Calr, Cd63, Dock8, Slc45a3, Rab37, Myl12b, Lpcat2, Sox4, Bin1, Alox5, Fam65a, Esyt1, Flnb, Prr13, Mpp4, Ubb, Anxa2, Scin, AK153427, Rac2
#
# Cluster 13Baso — top 50 markers:
# Prtn3, H2afy, Ctsg, Mpo, Lgals1, Emb, Coro1a, Pkm2, Vim, Psmb8, Laptm5, Calr, Cst3, Tyrobp, Igfbp4, Sh3bgrl3, Ly6e, Mapkapk2, Irf8, Ramp1, Lcp1, Tspo, Ly86, Arhgdib, F13a1, Selplg, Cd52, Arpc1b, Cd34, Sfpi1, Fxyd5, Csf1r, Limd2, Rac2, FKBP12-T1, Tagln2, Sell, Hsp90b1, Tpm3, Nme2, Fcer1g, Napsa, BC035044, Hint1, Tifab, Ms4a6c, Actb, Hspa5, Fam107b, P4hb
#
# Cluster 14Mo — top 50 markers:
# Prtn3, Mpo, Ctsg, Elane, Calr, H2afy, Pkm2, Lgals1, P4hb, Sh3bgrl3, Coro1a, Hp, Ramp1, Igfbp4, Emb, Cst3, Alas1, Psmb8, Tyrobp, Laptm5, Ly6c2, Arhgdib, Napsa, Arpc1b, Irf8, Gpx1, Tspo, Hsp90b1, Hexa, Manf, Mapkapk2, Sec61b, Hspa5, Krtcap2, Vim, Gnai2, Sepx1, Erp29, Ckap4, Fxyd5, Gstm1, Srgn, Gpi1, Limd2, Nme2, Selplg, Plod3, Lbp, Slpi, Rps6ka1
#
# Cluster 15Mo — top 50 markers:
# Elane, Prtn3, Mpo, Ctsg, Calr, Gstm1, Alas1, Srgn, P4hb, Arhgdib, Hsp90b1, Ly6c2, Hp, Hspa5, H2afy, Pkm2, Sun2, Nkg7, Ramp1, Gpi1, Mlec, Coro1a, Fcgr3, Napsa, Manf, Adssl1, 1190002H23Rik, C3, Serp1, Hdc, Emilin1, Etfb, Ckap4, Tmed3, Plod3, B4galt6, Igfbp4, Cst7, Cd63, Sepx1, Lbp, Rac2, Pgd, Gpc1, Sec61a1, Sh3bgrl3, Ssr2, Prdx5, Sfpi1, Tmbim6
#
# Cluster 16Neu — top 50 markers:
# Elane, Prtn3, Mpo, Ctsg, Gstm1, Calr, P4hb, Alas1, Srgn, Hp, Coro1a, Arhgdib, 1190002H23Rik, Napsa, Gpi1, Pkm2, Sun2, Prdx5, Rac2, Sh3bgrl3, Pglyrp1, Nkg7, Arpc1b, Ramp1, Adssl1, Rps6ka1, Tmbim6, Tkt, C3, Ckap4, Pgd, Gnai2, Ly6c2, Fcgr3, Cst3, Manf, B4galnt1, Lbp, Ssr2, Shfm1, Emilin1, Cd63, Limd2, Gpc1, Igfbp4, Impdh1, Rnaset2a, Hdc, Cebpe, Gsr
#
# Cluster 17Neu — top 50 markers:
# Srgn, Ly6e, Lmo4, Apoe, Calr, Prss34, Ctsg, Mcpt8, Mpo, Gata2, Atp6v0a1, Cebpa, Napsa, Man2b1, Ptprs, Laptm5, Alox5, Ptprcap, Gnas, Cd63, Lgals1, Csf1, Fam129a, Gm2a, Ets1, Fcer1g, Akap13, Ifitm1, Txnip, Itm2c, Fut7, Cd9, Fcgr3, Gpr56, Itga2b, Rin3, Gng12, Hdc, Nedd4, Csrp3, Prr13, H2-T10, Rnf130, Myl12b, Lcp1, Nucb1, Vim, Cdh1, Taldo1, Runx1
#
# Cluster 18Eos — top 50 markers:
# Calr, Prg2, Prg3, Nucb1, P4hb, Epx, Cebpe, Hdc, H2afy, Mpo, Tkt, Prtn3, Arsb, Dtnbp1, Ier3ip1, Cd63, Galnt6, Ifitm1, Spns3, Ptprs, Ctsh, Tcn2, Tacc1, Anxa5, Glud1, Ssr2, Man2b1, Gm2a, Dapp1, Laptm5, Itga2b, Atp5h, Rps8, Rab44, N4bp2l1, Nucb2, Arf1, Chst12, Arpc1b, Pglyrp1, Gm5057, Prss34, Myl12b, Pkm2, Cisd3, Pfkfb3, Tmem160, Atp6ap2, Lgals1, Arf4
#
# Cluster 19Lymph — top 50 markers:
# Ccl5, Cd52, Actb, Ctsw, H2-K1, Shisa5, Anxa2, Id2, Nkg7, Tyrobp, Sh3bgrl3, H2-D1, Selplg, Coro1a, Lck, Tcb, Ptprcap, Lsp1, Klrk1, Cd2, Klrb1c, Cd7, Ahnak, Tmsb10, Limd2, Laptm5, Gimap6, Sh2d2a, Fcer1g, Anxa6, Serpina3f, Cnn2, Nrgn, Xcl1, Gimap7, Itgb2, Zyx, Pglyrp1, Kbtbd11, Hcst, Epsti1, Ets1, Gimap5, S100a10, Gimap1, Ctsd, Il2rb, Rpl13a, 2310014H01Rik, Il16

# %%
adata.obs
# Out:
#        paul15_clusters leiden
# W31105            7MEP      6
# W31106            15Mo      7
# W31107            3Ery      1
# W31108            15Mo      3
# W31109            3Ery      1
# ...                ...    ...
# W39164            2Ery      0
# W39165          13Baso      4
# W39166            7MEP      6
# W39167            15Mo      3
# W39168            3Ery      1
#
# [2730 rows x 2 columns]

# %%
# How many clusters are there?
print(f"Number of clusters: {len(adata.obs['paul15_clusters'].unique())}")
adata.obs['paul15_clusters'].value_counts().sort_index()
# Out:
# Number of clusters: 19
# paul15_clusters
# 1Ery        43
# 2Ery       329
# 3Ery       246
# 4Ery       124
# 5Ery       180
# 6Ery       173
# 7MEP       167
# 8Mk         68
# 9GMP        63
# 10GMP      153
# 11DC        30
# 12Baso      69
# 13Baso     300
# 14Mo       373
# 15Mo       186
# 16Neu      164
# 17Neu       22
# 18Eos        9
# 19Lymph     31
# Name: count, dtype: int64

# %%
# !pip install -q celltypist
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 63.4 MB/s eta 0:00:00

# %%
# import celltypist

# # Run the default immune reference
# predictions = celltypist.annotate(
#     adata,
#     model='Immune_All_Low.pkl',    # or whichever fits your system
#     majority_voting=True,
#     cluster_support=True,
#     gpu=False 
# )

# # Add labels back to adata.obs
# adata.obs['cell_type_ct'] = predictions.predicted_labels

# %% [markdown]
# ### Call the Agent! Run the annotation

# %%
# Run annotation
adata = annotator.run(
    study_context="""
    Mouse bone marrow cells undergoing myeloid differentiation. This includes several subtypes of immune cell progenitors.

    """
)

# View results
#print(adata.obs.cytetype_leiden)
# Out:
# CyteType job (id: 1e775ae4-5995-49e4-a47b-8841d1ad3f28) submitted. Polling for results...
# Report (updates automatically) available at: https://nygen-labs-prod--cytetype-api.modal.run/report/1e775ae4-5995-49e4-a47b-8841d1ad3f28
# If network disconnects, the results can still be fetched:
# `results = annotator.get_results()`
# [DONE] [✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓] 19/19 completed
# Job 1e775ae4-5995-49e4-a47b-8841d1ad3f28 completed successfully.
# Annotations successfully added to `adata.obs['cytetype_annotation_paul15_clusters']`
# Ontology terms added to `adata.obs['cytetype_cellOntologyTerm_paul15_clusters']`
# Full results added to `adata.uns['cytetype_results']`.

# %% [markdown]
# ### Compare annotation with existing one
#
# The original annotation are more granular than the ones from Cytetype, so we manually create a dictionary to make a comparison.

# %%
print(adata.obs)
# Out:
#        paul15_clusters leiden cytetype_annotation_paul15_clusters  \
# W31105            7MEP      6                  Myeloid Progenitor
# W31106            15Mo      7               Neutrophil Progenitor
# W31107            3Ery      1                Erythroid Progenitor
# W31108            15Mo      3               Neutrophil Progenitor
# W31109            3Ery      1                Erythroid Progenitor
# ...                ...    ...                                 ...
# W39164            2Ery      0                Erythroid Progenitor
# W39165          13Baso      4     Granulocyte-Monocyte Progenitor
# W39166            7MEP      6                  Myeloid Progenitor
# W39167            15Mo      3               Neutrophil Progenitor
# W39168            3Ery      1                Erythroid Progenitor
#
#        cytetype_cellOntologyTerm_paul15_clusters
# W31105                                CL_0000049
# W31106                                CL_0000834
# W31107                                CL_0000038
# W31108                                CL_0000834
# W31109                                CL_0000038
# ...                                          ...
# W39164                                CL_0000038
# W39165                                CL_0000557
# W39166                                CL_0000049
# W39167                                CL_0000834
# W39168                                CL_0000038
#
# [2730 rows x 4 columns]

# %%
print(adata.obs.cytetype_annotation_paul15_clusters.unique().to_list())
# Out:
# ['Myeloid Progenitor', 'Neutrophil Progenitor', 'Erythroid Progenitor', 'Neutrophil Precursor', 'Granulocyte-Monocyte Progenitor', 'Megakaryocyte Progenitor', 'Natural Killer Cell', 'Common Myeloid Progenitor', 'Myeloid Progenitor Cell']
# /tmp/ipykernel_13/2255399537.py:1: FutureWarning: Categorical.to_list is deprecated and will be removed in a future version. Use obj.tolist() instead
#   print(adata.obs.cytetype_annotation_paul15_clusters.unique().to_list())

# %%
label_map = {
    '1Ery': 'Erythroblast',
    '2Ery': 'Erythroid precursor',
    '3Ery': 'Erythroblast',
    '4Ery': 'Erythroid precursor',
    '5Ery': 'Erythroid cell',
    '6Ery': 'Erythroid progenitor',

    '7MEP': 'Myeloid progenitor cell',
    '8Mk': 'Megakaryocyte',
    '9GMP': 'Hematopoietic progenitor cell',
    '10GMP': 'Hematopoietic progenitor cell',

    '11DC': 'Antigen-presenting myeloid cell',
    '12Baso': 'Mast cell',
    '13Baso': 'Mast cell',

    '14Mo': 'Neutrophil promyelocyte',
    '15Mo': 'Neutrophil promyelocyte',

    '16Neu': 'Neutrophil',
    '17Neu': 'Neutrophil',

    '18Eos': 'Eosinophil',
    '19Lymph': 'Natural Killer (NK) cell'
}

# %%
adata.obs["true_broad"] = adata.obs["cytetype_annotation_paul15_clusters"].map(label_map)

conf_mat = pd.crosstab(adata.obs["true_broad"], adata.obs["cytetype_annotation_paul15_clusters"], normalize='index')
conf_mat
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
conf_mat
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# # Plot Confusion matrix
# plt.figure(figsize=(10, 6))
# sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt=".2f", cbar=True)
# plt.title("CyteType vs Paul15 Broad Cell Type Mapping")
# plt.ylabel("True Label (Paul15 Broad)")
# plt.xlabel("Predicted Label (CyteType)")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Repeating the confusion matrix, using the original labels
#
#
# In the code above we had to manually match the Paul 15 labels with the ones generated by cytetype. Here we use the original lables, although we expand them to make it more readable, and we keep the original values.

# %%
import pandas as pd

# Step 1: Mapping from cluster ID to full name
paul15_label_fullname = {
    '1Ery': '1Ery - Early erythroid progenitors',
    '2Ery': '2Ery - Intermediate erythroid stage',
    '3Ery': '3Ery - Late erythroid / erythroblast',
    '4Ery': '4Ery - Terminally differentiating erythrocytes',
    '5MEP': '5MEP - Megakaryocyte-Erythroid Progenitor',
    '6MEP': '6MEP - Megakaryocyte-Erythroid Progenitor (more mature)',
    '7MEP': '7MEP - Megakaryocyte-Erythroid Progenitor (late stage)',
    '8GMP': '8GMP Granulocyte–monocyte progenitor',
    '9DC':  '9DC - Dendritic cell progenitors',
    '10Baso': '10Baso - Basophil progenitors',
    '11Mo': '11Mo - Monocyte progenitors',
    '12Mo': '12Mo - Differentiated monocyte progenitors',
    '13Baso': '13Baso - Mature basophil progenitors',
    '14Mo': '14Mo - Late-stage monocytes',
    '15Mo': '15Mo - Mature monocytes',
    '16Neu': '16Neu - Neutrophil progenitors',
    '17Neu': '17Neu - Late-stage neutrophils',
    '18Eos': '18Eos - Eosinophil progenitors',
    '19Lymph': '19Lymph - Lymphoid-like cells (NK/T precursors or contaminants)',
}

# Step 2: Map full names into obs
adata.obs["paul15_fullname"] = adata.obs["paul15_clusters"].map(paul15_label_fullname)
adata.obs.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#        paul15_clusters leiden cytetype_annotation_paul15_clusters  \
# W31105            7MEP      6                  Myeloid Progenitor
# W31106            15Mo      7               Neutrophil Progenitor
# W31107            3Ery      1                Erythroid Progenitor
# W31108            15Mo      3               Neutrophil Progenitor
# W31109            3Ery      1                Erythroid Progenitor
#
#        cytetype_cellOntologyTerm_paul15_clusters  true_broad  \
# W31105                                CL_0000049         NaN
# W31106                                CL_0000834         NaN
# W31107                                CL_0000038         NaN
# W31108                                CL_0000834         NaN
# W31109                                CL_0000038         NaN
#
#                                           paul15_fullname
# W31105  7MEP - Megakaryocyte-Erythroid Progenitor (lat...
# W31106                            15Mo - Mature monocytes
# W31107               3Ery - Late erythroid / erythroblast
# W31108                            15Mo - Mature monocytes
# W31109               3Ery - Late erythroid / erythroblast

# %%
adata.obs.cytetype_annotation_paul15_clusters.value_counts()
# Out:
# cytetype_annotation_paul15_clusters
# Erythroid Progenitor               1095
# Myeloid Progenitor                  405
# Neutrophil Precursor                373
# Neutrophil Progenitor               350
# Granulocyte-Monocyte Progenitor     309
# Common Myeloid Progenitor            69
# Megakaryocyte Progenitor             68
# Natural Killer Cell                  31
# Myeloid Progenitor Cell              30
# Name: count, dtype: int64

# %%
# Step 3: Define full-name order
manual_order_full = list(paul15_label_fullname.values())


# Step 4: Create and reorder confusion matrix
conf_mat_full = pd.crosstab(
    adata.obs["paul15_fullname"],
    adata.obs["cytetype_annotation_paul15_clusters"],
    normalize='index'
)
# Only keep labels that exist in the confusion matrix
existing_labels = [label for label in manual_order_full if label in conf_mat_full.index]

# Reorder based on existing labels only
conf_mat_ordered = conf_mat_full.loc[existing_labels]

# Optional: reorder columns if matching set
if all(label in conf_mat_ordered.columns for label in manual_order_full):
    conf_mat_ordered = conf_mat_ordered[manual_order_full]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(conf_mat_ordered, annot=True, fmt=".2f", cmap="Blues", cbar=True)

plt.title("Confusion Matrix (Original Cluster Names, Ordered by Manual Mapping)")
plt.xlabel("Predicted Label")
plt.ylabel("Original Cluster")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
adata.obs.groupby(["cytetype_annotation_paul15_clusters", "paul15_clusters"]).size().reset_index().rename(columns={0:'cell_count'}).\
    query("cell_count>0").sort_values("paul15_clusters").drop(columns="cell_count").style.background_gradient(axis=None)
# Out:
# /tmp/ipykernel_13/3959061399.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs.groupby(["cytetype_annotation_paul15_clusters", "paul15_clusters"]).size().reset_index().rename(columns={0:'cell_count'}).\
# <style type="text/css">
# </style>
# <table id="T_fb667">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb667_level0_col0" class="col_heading level0 col0" >cytetype_annotation_paul15_clusters</th>
#       <th id="T_fb667_level0_col1" class="col_heading level0 col1" >paul15_clusters</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb667_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_fb667_row0_col0" class="data row0 col0" >Erythroid Progenitor</td>
#       <td id="T_fb667_row0_col1" class="data row0 col1" >1Ery</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_fb667_row1_col0" class="data row1 col0" >Erythroid Progenitor</td>
#       <td id="T_fb667_row1_col1" class="data row1 col1" >2Ery</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row2" class="row_heading level0 row2" >21</th>
#       <td id="T_fb667_row2_col0" class="data row2 col0" >Erythroid Progenitor</td>
#       <td id="T_fb667_row2_col1" class="data row2 col1" >3Ery</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_fb667_row3_col0" class="data row3 col0" >Erythroid Progenitor</td>
#       <td id="T_fb667_row3_col1" class="data row3 col1" >4Ery</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row4" class="row_heading level0 row4" >23</th>
#       <td id="T_fb667_row4_col0" class="data row4 col0" >Erythroid Progenitor</td>
#       <td id="T_fb667_row4_col1" class="data row4 col1" >5Ery</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row5" class="row_heading level0 row5" >24</th>
#       <td id="T_fb667_row5_col0" class="data row5 col0" >Erythroid Progenitor</td>
#       <td id="T_fb667_row5_col1" class="data row5 col1" >6Ery</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row6" class="row_heading level0 row6" >82</th>
#       <td id="T_fb667_row6_col0" class="data row6 col0" >Myeloid Progenitor</td>
#       <td id="T_fb667_row6_col1" class="data row6 col1" >7MEP</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row7" class="row_heading level0 row7" >64</th>
#       <td id="T_fb667_row7_col0" class="data row7 col0" >Megakaryocyte Progenitor</td>
#       <td id="T_fb667_row7_col1" class="data row7 col1" >8Mk</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row8" class="row_heading level0 row8" >84</th>
#       <td id="T_fb667_row8_col0" class="data row8 col0" >Myeloid Progenitor</td>
#       <td id="T_fb667_row8_col1" class="data row8 col1" >9GMP</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row9" class="row_heading level0 row9" >85</th>
#       <td id="T_fb667_row9_col0" class="data row9 col0" >Myeloid Progenitor</td>
#       <td id="T_fb667_row9_col1" class="data row9 col1" >10GMP</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row10" class="row_heading level0 row10" >105</th>
#       <td id="T_fb667_row10_col0" class="data row10 col0" >Myeloid Progenitor Cell</td>
#       <td id="T_fb667_row10_col1" class="data row10 col1" >11DC</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fb667_row11_col0" class="data row11 col0" >Common Myeloid Progenitor</td>
#       <td id="T_fb667_row11_col1" class="data row11 col1" >12Baso</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row12" class="row_heading level0 row12" >50</th>
#       <td id="T_fb667_row12_col0" class="data row12 col0" >Granulocyte-Monocyte Progenitor</td>
#       <td id="T_fb667_row12_col1" class="data row12 col1" >13Baso</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row13" class="row_heading level0 row13" >146</th>
#       <td id="T_fb667_row13_col0" class="data row13 col0" >Neutrophil Precursor</td>
#       <td id="T_fb667_row13_col1" class="data row13 col1" >14Mo</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row14" class="row_heading level0 row14" >166</th>
#       <td id="T_fb667_row14_col0" class="data row14 col0" >Neutrophil Progenitor</td>
#       <td id="T_fb667_row14_col1" class="data row14 col1" >15Mo</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row15" class="row_heading level0 row15" >167</th>
#       <td id="T_fb667_row15_col0" class="data row15 col0" >Neutrophil Progenitor</td>
#       <td id="T_fb667_row15_col1" class="data row15 col1" >16Neu</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row16" class="row_heading level0 row16" >92</th>
#       <td id="T_fb667_row16_col0" class="data row16 col0" >Myeloid Progenitor</td>
#       <td id="T_fb667_row16_col1" class="data row16 col1" >17Neu</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row17" class="row_heading level0 row17" >55</th>
#       <td id="T_fb667_row17_col0" class="data row17 col0" >Granulocyte-Monocyte Progenitor</td>
#       <td id="T_fb667_row17_col1" class="data row17 col1" >18Eos</td>
#     </tr>
#     <tr>
#       <th id="T_fb667_level0_row18" class="row_heading level0 row18" >132</th>
#       <td id="T_fb667_row18_col0" class="data row18 col0" >Natural Killer Cell</td>
#       <td id="T_fb667_row18_col1" class="data row18 col1" >19Lymph</td>
#     </tr>
#   </tbody>
# </table>

# %%
adata.obs[["paul15_fullname"]].value_counts()
# Out:
# paul15_fullname
# 14Mo - Late-stage monocytes                                        373
# 2Ery - Intermediate erythroid stage                                329
# 13Baso - Mature basophil progenitors                               300
# 3Ery - Late erythroid / erythroblast                               246
# 15Mo - Mature monocytes                                            186
# 7MEP - Megakaryocyte-Erythroid Progenitor (late stage)             167
# 16Neu - Neutrophil progenitors                                     164
# 4Ery - Terminally differentiating erythrocytes                     124
# 1Ery - Early erythroid progenitors                                  43
# 19Lymph - Lymphoid-like cells (NK/T precursors or contaminants)     31
# 17Neu - Late-stage neutrophils                                      22
# 18Eos - Eosinophil progenitors                                       9
# Name: count, dtype: int64

# %%
adata.obs[["cytetype_annotation_paul15_clusters", "paul15_fullname"]].value_counts()
# Out:
# cytetype_annotation_paul15_clusters  paul15_fullname
# Neutrophil Precursor                 14Mo - Late-stage monocytes                                        373
# Erythroid Progenitor                 2Ery - Intermediate erythroid stage                                329
# Granulocyte-Monocyte Progenitor      13Baso - Mature basophil progenitors                               300
# Erythroid Progenitor                 3Ery - Late erythroid / erythroblast                               246
# Neutrophil Progenitor                15Mo - Mature monocytes                                            186
# Myeloid Progenitor                   7MEP - Megakaryocyte-Erythroid Progenitor (late stage)             167
# Neutrophil Progenitor                16Neu - Neutrophil progenitors                                     164
# Erythroid Progenitor                 4Ery - Terminally differentiating erythrocytes                     124
#                                      1Ery - Early erythroid progenitors                                  43
# Natural Killer Cell                  19Lymph - Lymphoid-like cells (NK/T precursors or contaminants)     31
# Myeloid Progenitor                   17Neu - Late-stage neutrophils                                      22
# Granulocyte-Monocyte Progenitor      18Eos - Eosinophil progenitors                                       9
# Name: count, dtype: int64

# %%
adata.obs
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#        paul15_clusters leiden cytetype_annotation_paul15_clusters  \
# W31105            7MEP      6                  Myeloid Progenitor
# W31106            15Mo      7               Neutrophil Progenitor
# W31107            3Ery      1                Erythroid Progenitor
# W31108            15Mo      3               Neutrophil Progenitor
# W31109            3Ery      1                Erythroid Progenitor
# ...                ...    ...                                 ...
# W39164            2Ery      0                Erythroid Progenitor
# W39165          13Baso      4     Granulocyte-Monocyte Progenitor
# W39166            7MEP      6                  Myeloid Progenitor
# W39167            15Mo      3               Neutrophil Progenitor
# W39168            3Ery      1                Erythroid Progenitor
#
#        cytetype_cellOntologyTerm_paul15_clusters  true_broad  \
# W31105                                CL_0000049         NaN
# W31106                                CL_0000834         NaN
# W31107                                CL_0000038         NaN
# W31108                                CL_0000834         NaN
# W31109                                CL_0000038         NaN
# ...                                          ...         ...
# W39164                                CL_0000038         NaN
# W39165                                CL_0000557         NaN
# W39166                                CL_0000049         NaN
# W39167                                CL_0000834         NaN
# W39168                                CL_0000038         NaN
#
#                                           paul15_fullname
# W31105  7MEP - Megakaryocyte-Erythroid Progenitor (lat...
# W31106                            15Mo - Mature monocytes
# W31107               3Ery - Late erythroid / erythroblast
# W31108                            15Mo - Mature monocytes
# W31109               3Ery - Late erythroid / erythroblast
# ...                                                   ...
# W39164                2Ery - Intermediate erythroid stage
# W39165               13Baso - Mature basophil progenitors
# W39166  7MEP - Megakaryocyte-Erythroid Progenitor (lat...
# W39167                            15Mo - Mature monocytes
# W39168               3Ery - Late erythroid / erythroblast
#
# [2730 rows x 6 columns]

# %%
#sc.pl.embedding(adata, basis='umap', color='cytetype_annotation_cell_type')

# %% [markdown]
# ## What if we give the wrong description?
#
# Let's give a wrong instruction to CyteType, for example by saying that this is a retina dataset in Zebrafish, to see if it still returns good results

# %%
adata2 = adata.copy()
# Initialize CyteType (performs data preparation)
annotator = cytetype.CyteType(
    adata2,
    group_key='paul15_clusters',
    rank_key='rank_genes_groups',
    gene_symbols_column='gene_symbols',
    n_top_genes=50,
)
# Out:
# Using coordinates from 'X_pca' for visualization.
# Calculating expression percentages.
# Extracting marker genes.
# Preparing visualization data with sampling.
# Using first 2 dimensions of 'X_pca' for visualization.
# Extracted 2730 coordinate points (sampled from 2730 total cells)
# Data preparation completed. Ready for submitting jobs.

# %%
adata2 = annotator.run(
    study_context="Zebrafish retina development during embryogenesis"
)
# Out:
# CyteType job (id: 4e7ce9a5-16e3-419d-92a4-ef4deb5666d0) submitted. Polling for results...
# Report (updates automatically) available at: https://nygen-labs-prod--cytetype-api.modal.run/report/4e7ce9a5-16e3-419d-92a4-ef4deb5666d0
# If network disconnects, the results can still be fetched:
# `results = annotator.get_results()`
# [DONE] [✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓✓] 19/19 completed
# Job 4e7ce9a5-16e3-419d-92a4-ef4deb5666d0 completed successfully.
# Annotations successfully added to `adata.obs['cytetype_annotation_paul15_clusters']`
# Ontology terms added to `adata.obs['cytetype_cellOntologyTerm_paul15_clusters']`
# Full results added to `adata.uns['cytetype_results']`.

# %%
# adata2.obs["true_broad"] = adata2.obs["paul15_clusters"].map(label_map)

# pd.crosstab(adata2.obs["true_broad"], adata2.obs["cytetype_paul15_clusters"], normalize='index')

# %%
# adata2.obs["paul15_fullname"] = adata2.obs["paul15_clusters"].map(paul15_label_fullname)

# %%
# # Create normalized confusion matrix
# conf_mat = pd.crosstab(
#     adata2.obs["true_broad"],
#     adata2.obs["cytetype_paul15_clusters"],
#     normalize='index'
# )

# # Plot with seaborn
# plt.figure(figsize=(10, 6))
# sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt=".2f", cbar=True)
# plt.title("CyteType vs Paul15 Broad Cell Type Mapping")
# plt.ylabel("True Label (Paul15 Broad)")
# plt.xlabel("Predicted Label (CyteType)")
# plt.tight_layout()
# plt.show()

# %%
# # Let's also look at the Confusion matrix with the original cluster names
# conf_mat_original = pd.crosstab(adata2.obs["paul15_clusters"], adata2.obs["cytetype_paul15_clusters"], normalize='index')
# conf_mat_original



# # Step 3: Define full-name order
# manual_order_full = list(paul15_label_fullname.values())


# # Step 4: Create and reorder confusion matrix
# conf_mat_full = pd.crosstab(
#     adata2.obs["paul15_fullname"],
#     adata2.obs["cytetype_paul15_clusters"],
#     normalize='index'
# )
# # Only keep labels that exist in the confusion matrix
# existing_labels = [label for label in manual_order_full if label in conf_mat_full.index]

# # Reorder based on existing labels only
# conf_mat_ordered = conf_mat_full.loc[existing_labels]

# # Optional: reorder columns if matching set
# if all(label in conf_mat_ordered.columns for label in manual_order_full):
#     conf_mat_ordered = conf_mat_ordered[manual_order_full]

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 10))
# sns.heatmap(conf_mat_ordered, annot=True, fmt=".2f", cmap="Blues", cbar=True)

# plt.title("Confusion Matrix (Original Cluster Names, Ordered by Manual Mapping) - using a wrong study context")
# plt.xlabel("Predicted Label")
# plt.ylabel("Original Cluster")
# plt.xticks(rotation=90)
# plt.yticks(rotation=0)
# plt.tight_layout()
# plt.show()
